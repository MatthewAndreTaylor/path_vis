# %%
# %pip install path_vis numpy

# %%
import numpy as np
from path_vis import PathVis

# %% [markdown]
# # Piecewise Constant Curvature (PCC) with standard state parameterization
#
# kappa (𝜅), phi (𝜙), l (ℓ)

# %%
def rotz(phi):
    c, s = np.cos(phi), np.sin(phi)
    R = np.eye(4)
    R[:2, :2] = [[c, -s], [s, c]]
    return R

def roty(theta):
    c, s = np.cos(theta), np.sin(theta)
    R = np.eye(4)
    R[0, 0], R[0, 2] = c, s
    R[2, 0], R[2, 2] = -s, c
    return R

def segment_matrix(k, phi, s):
    if abs(k) < 1e-9:
        seg = np.eye(4)
        seg[2, 3] = s
    else:
        theta, r = k * s, 1 / k
        seg = roty(theta)
        seg[0, 3] = r * (1 - np.cos(theta))
        seg[2, 3] = r * np.sin(theta)
        seg = rotz(phi) @ seg @ rotz(-phi)
    return seg

def pcc_standard(kappa, l, phi, n=10):
    curr_frame = np.eye(4)
    curve = [ curr_frame.copy() ]

    for ki, li, pi in zip(kappa, l, phi):
        for j in range(1, n + 1):
            seg = curr_frame @ segment_matrix(ki, pi, j * li / n)
            curve.append(seg)
        curr_frame @= segment_matrix(ki, pi, li)
    
    return np.concatenate([c.ravel() for c in curve]).tolist()

# %% [markdown]
# Random configurations

# %%
rng = np.random.default_rng()
kappa = rng.uniform(0,20,3)
phi = rng.uniform(0, 2*np.pi, 3)
l = rng.uniform(0.1,0.3,3)
PathVis(pcc_standard(kappa, l, phi))

# %% [markdown]
# Notice that even with varying values of phi (𝜙) each segment remains straight

# %%
kappa = np.zeros(3)
phi = rng.uniform(0, 2*np.pi, 3)
l = np.array([0.2] * 3)

print(phi)
PathVis(pcc_standard(kappa, l, phi))

# %% [markdown]
# # q-parameterization
#
# Dx (Δx), Dy (Δy), dL (δL)

# %%
def segment_matrix_q(Dx, Dy, dL, L0=0.01, d=1.0):
    seg = np.eye(4)
    Delta = np.sqrt(Dx**2 + Dy**2)
    L = L0 + dL

    if Delta < 1e-9:
        # straight configuration (well-defined limit)
        seg[2, 3] = L
        return seg

    c = np.cos(Delta / d)
    s = np.sin(Delta / d)

    # Rotation
    R = np.array([
        [1 + (Dx**2/Delta**2)*(c-1), (Dx*Dy/Delta**2)*(c-1), -Dx/Delta*s],
        [(Dx*Dy/Delta**2)*(c-1), 1 + (Dy**2/Delta**2)*(c-1), -Dy/Delta*s],
        [Dx/Delta*s, Dy/Delta*s, c]
    ])

    seg[:3, :3] = R

    # Translation
    seg[0, 3] = d * L / (Delta**2) * Dx * (1 - c)
    seg[1, 3] = d * L / (Delta**2) * Dy * (1 - c)
    seg[2, 3] = d * L / (Delta**2) * Delta * s
    return seg


def pcc_q(Dx, Dy, dL, n=10):
    curr_frame = np.eye(4)
    curve = [curr_frame.copy()]

    for dx, dy, dl in zip(Dx, Dy, dL):
        dx_s, dy_s, dl_s = dx / n, dy / n, dl / n

        for _ in range(n):
            seg = curr_frame @ segment_matrix_q(dx_s, dy_s, dl_s)
            curve.append(seg)
            curr_frame = seg

    return np.concatenate([c.ravel() for c in curve]).tolist()

# %%
rng = np.random.default_rng()
Dx = rng.uniform(-2, 2, 3)
Dy = rng.uniform(-2, 2, 3)
dL = rng.uniform(0.1, 0.3, 3)

PathVis(pcc_q(Dx, Dy, dL))

# %% [markdown]
# Notice that unless both Dx and Dy are zero there is still bending

# %%
Dx = rng.uniform(-2, 2, 3)
Dy = np.zeros(3)
dL = np.array([0.2] * 3)

PathVis(pcc_q(Dx, Dy, dL))

# %%
Dx = np.zeros(3)
Dy = np.zeros(3)
dL = np.array([0.2] * 3)

PathVis(pcc_q(Dx, Dy, dL))

# %% [markdown]
# # Example fk for 3 segment configuration

# %%
def continuum_fk(q, b_lengths):
    kappa, l, phi = np.zeros(3), np.zeros(3), np.zeros(3)
    
    for i in range(3):
        dt = q[3*i:3*i+3]
        
        if abs(sum(dt)) > 1e-6:
            raise ValueError("Tendon displacements must sum to zero for each segment.")
        
        phi_i, kappa_i = 0.0, 0.0
        
        if not np.allclose(dt, 0):
            l_ti = [b_lengths[i] + dt[j] for j in range(3)]
            kappa_i = 2 * np.sqrt( l_ti[0]**2 + l_ti[1]**2 + l_ti[2]**2 - l_ti[0]*l_ti[1] - l_ti[1]*l_ti[2] - l_ti[2]*l_ti[0] ) / (l_ti[0] + l_ti[1] + l_ti[2])
            phi_i = np.atan2(3*(l_ti[2] - l_ti[1]), np.sqrt(3) * (l_ti[1] + l_ti[2] - 2*l_ti[0]))
            
        kappa[i] = kappa_i
        phi[i] = phi_i
        l[i] = b_lengths[i]
        
    return pcc_standard(kappa, l, phi)

# %%
# lst = [-0.5, -0.5, 1.0, -0.8, 1.6, -0.8, -0.5, -0.5, 1.0]
lst = [2.0, -1.0, -1.0, 2.4, -1.2, -1.2, 2.8, -1.4, -1.4]

path = continuum_fk(lst, [0.2, 0.2, 0.2])
print(np.array(path[-16:]).reshape(4, 4)) # print the ee frame

PathVis(path)

# %% [markdown]
# Motion planning

# %%
from IPython.display import display

def log_(T):
    R = T[0:3, 0:3]
    p = T[0:3, 3]
    theta = np.acos(0.5 * (np.trace(R) - 1))

    if abs(theta) < 1e-6 or np.isnan(theta):
        theta = np.linalg.norm(p)
        omega_skew = np.eye(3)
        v = p / theta
    else:
        omega_skew = (R - R.T) / (2*np.sin(theta))
        cot_half = np.cos(theta/2) / np.sin(theta/2)
        G_inv = (
            (1/theta) * np.eye(3)
            - 0.5 * omega_skew
            + (1/theta - 0.5 * cot_half) * (omega_skew @ omega_skew)
        )
        v = G_inv @ p

    s = np.zeros((4,4))
    s[0:3, 0:3] = omega_skew * theta
    s[0:3, 3] = v * theta
    return s

class SimpleMotionPlan:
    def __init__(self, q_start):
        self.b_lengths = [0.2, 0.2, 0.2]
        self.current_config = q_start
        self.curr_path = continuum_fk(q_start, self.b_lengths)
        self.ee_frame = np.array(self.curr_path[-16:]).reshape(4, 4)
        self.vis = PathVis(self.curr_path)
        display(self.vis)
        
    def body_jacobian(self, q):
        epsilon = 1e-4
        j = np.zeros((6, 6))
        init_path = continuum_fk(q, self.b_lengths)
        init_ee = np.array(init_path[-16:]).reshape(4, 4)
        for i in range(6):
            q_i = q.copy()
            group = i // 2
            q_i[3 * group + (i % 2)] += epsilon
            q_i[3 * group + 2] -= epsilon
            perturbed_path = continuum_fk(q_i, self.b_lengths)
            perturbed_ee = np.array(perturbed_path[-16:]).reshape(4, 4)
            s_skew = log_(np.linalg.inv(init_ee) @ perturbed_ee)
            j[:, i] = np.array([
                s_skew[2, 1],
                s_skew[0, 2],
                s_skew[1, 0],
                s_skew[0, 3],
                s_skew[1, 3],
                s_skew[2, 3]
            ]) / epsilon
        return j

    def ctrl_it(self, target_xform, gain=0.1):
        self.vis.target_xform = target_xform.ravel().tolist()
        curr_xform = self.ee_frame
        bd_xform = np.linalg.inv(curr_xform) @ target_xform
        s_skew = log_(bd_xform)
        s_skew_se3 = np.array([
            s_skew[2, 1],
            s_skew[0, 2],
            s_skew[1, 0],
            s_skew[0, 3],
            s_skew[1, 3],
            s_skew[2, 3]
        ])
        s_skew_se3 *= gain
        j = self.body_jacobian(self.current_config)
        
        # moore-penrose pseudo-inverse + damped least-squares
        j_plus = j.T @ np.linalg.inv(j @ j.T + 1e-4 * np.eye(6))
        dq = j_plus @ s_skew_se3
        
        for b in range(3):
            base = 3 * b
            self.current_config[base + 0] += dq[2*b + 0]
            self.current_config[base + 1] += dq[2*b + 1]
            self.current_config[base + 2] -= dq[2*b + 0] + dq[2*b + 1]
        
        self.curr_path = continuum_fk(self.current_config, self.b_lengths)
        self.ee_frame = np.array(self.curr_path[-16:]).reshape(4, 4)
        self.vis.path = self.curr_path

# %%
import time

mp = SimpleMotionPlan(np.zeros(9))
target_xform = np.eye(4)
target_xform[:3, 3] = np.array([0.25, 0.1, 0.1])

for _ in range(100):
    time.sleep(0.02)
    mp.ctrl_it(target_xform)
